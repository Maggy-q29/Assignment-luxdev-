# %%
import requests
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# #### How to get API

# %%
url="https://api.football-data.org/v4/competitions/PL/matches?season=2024"
headers=({"x-auth-token":"4edd132d64ca4d309d5e53ab8ecd365e"})
response= requests.get(url,headers=headers)
data=response.json()

# %%
import json
print (json.dumps(data,indent=2))
# Out:
# {
#   "filters": {
#     "season": 2024
#   },
#   "resultSet": {
#     "count": 380,
#     "first": "2024-08-16",
#     "last": "2025-05-25",
#     "played": 380
#   },
#   "competition": {
#     "id": 2021,
#     "name": "Premier League",
#     "code": "PL",
#     "type": "LEAGUE",
#     "emblem": "https://crests.football-data.org/PL.png"
#   },
#   "matches": [
#     {
#       "area": {
#         "id": 2072,
#         "name": "England",
#         "code": "ENG",
#         "flag": "https://crests.football-data.org/770.svg"
#       },
#       "competition": {
#         "id": 2021,
#         "name": "Premier League",
#         "code": "PL",
#         "type": "LEAGUE",
#         "emblem": "https://crests.football-data.org/PL.png"
#       },
#       "season": {
#         "id": 2287,
#         "startDate": "2024-08-16",
#         "endDate": "2025-05-25",
#         "currentMatchday": 38,
#         "winner": null
#       },
#       "id": 497410,
#       "utcDate": "2024-08-16T19:00:00Z",
# ...

# %%
# matches
season_matches=data['matches']

# %%
df=pd.json_normalize(season_matches)
df.head()
# Out:
#        id               utcDate    status  matchday           stage group  \
# 0  497410  2024-08-16T19:00:00Z  FINISHED         1  REGULAR_SEASON  None
# 1  497411  2024-08-17T11:30:00Z  FINISHED         1  REGULAR_SEASON  None
# 2  497412  2024-08-17T14:00:00Z  FINISHED         1  REGULAR_SEASON  None
# 3  497413  2024-08-17T14:00:00Z  FINISHED         1  REGULAR_SEASON  None
# 4  497414  2024-08-17T14:00:00Z  FINISHED         1  REGULAR_SEASON  None
#
#             lastUpdated                                           referees  \
# 0  2025-06-08T20:20:25Z  [{'id': 11446, 'name': 'Robert Jones', 'type':...
# 1  2025-06-08T20:20:25Z  [{'id': 11396, 'name': 'Tim Robinson', 'type':...
# 2  2025-06-08T20:20:25Z  [{'id': 23568, 'name': 'Jarred Gillett', 'type...
# 3  2025-06-08T20:20:25Z  [{'id': 11430, 'name': 'Simon Hooper', 'type':...
# 4  2025-06-08T20:20:25Z  [{'id': 11585, 'name': 'Craig Pawson', 'type':...
#
#    area.id area.name  ... awayTeam.shortName awayTeam.tla  \
# ...

# %%
season_matches_1=df[[
    "matchday",
    "homeTeam.name",
    "awayTeam.name", 
    "score.fullTime.home",
    "score.fullTime.away",
    "status",
    "utcDate"
]].rename(columns={
         "homeTeam.name":"HomeTeam",
         "awayTeam.name":"AwayTeam",
         "score.fullTime.home":"HomeScore",
         "score.fullTime.away":"AwayScore",
         "utcDate":"Date"
})

# %%
season_matches_1.head()
# Out:
#    matchday              HomeTeam                    AwayTeam  HomeScore  \
# 0         1  Manchester United FC                   Fulham FC          1
# 1         1       Ipswich Town FC                Liverpool FC          0
# 2         1            Arsenal FC  Wolverhampton Wanderers FC          2
# 3         1            Everton FC   Brighton & Hove Albion FC          0
# 4         1   Newcastle United FC              Southampton FC          1
#
#    AwayScore    status                  Date
# 0          0  FINISHED  2024-08-16T19:00:00Z
# 1          2  FINISHED  2024-08-17T11:30:00Z
# 2          0  FINISHED  2024-08-17T14:00:00Z
# 3          3  FINISHED  2024-08-17T14:00:00Z
# 4          0  FINISHED  2024-08-17T14:00:00Z

# %%
season_matches_1.to_csv("Teams2024.csv", index=False)

# %%
team_stats={}
for _, row in  season_matches_1.iterrows():
    if row ["status"] !="FINISHED":
        continue 

    away= row["AwayTeam"]
    home= row["HomeTeam"]
    home_score= row["HomeScore"]
    away_score= row["AwayScore"]

    for team in[home, away]:
        if team not in team_stats:
            team_stats[team]={"played":0, "won":0} 
        team_stats[team] ["played"]+=1

    if home_score > away_score:
        team_stats[home] ["won"]+=1
    elif away_score > home_score:
        team_stats[away] ["won"]+=1

# %%
prob_win={
    team: round (stats["won"]/stats["played"],3 )
    for team, stats in team_stats.items()
}

# %%
teams_probability=pd.DataFrame(
    [(team, stats["played"],stats["won"],prob_win[team])
    for team, stats in team_stats.items()],
    columns= ["team","matches_played","matches_won","prob_win"]
).sort_values(by="prob_win", ascending=False)

print(teams_probability)
# Out:
#                           team  matches_played  matches_won  prob_win
# 3                 Liverpool FC              38           25     0.658
# 17          Manchester City FC              38           21     0.553
# 4                   Arsenal FC              38           20     0.526
# 16                  Chelsea FC              38           20     0.526
# 8          Newcastle United FC              38           20     0.526
# 10        Nottingham Forest FC              38           19     0.500
# 13              Aston Villa FC              38           19     0.500
# 7    Brighton & Hove Albion FC              38           16     0.421
# 14                Brentford FC              38           16     0.421
# 1                    Fulham FC              38           15     0.395
# 11             AFC Bournemouth              38           15     0.395
# 15           Crystal Palace FC              38           13     0.342
# ...

# %% [markdown]
# - based on top performance in the last season the top teams that had the highest probability of winning was Liverpool FC
# - While team  below had a 50% chance of winning
# 17          Manchester City FC              38           21     0.553
# 4                   Arsenal FC              38           20     0.526
# 16                  Chelsea FC              38           20     0.526
# 8          Newcastle United FC              38           20     0.526
# 10        Nottingham Forest FC              38           19     0.500
# 13              Aston Villa FC              38           19     0.500
#
# what to do:
# . The clubs(teams) need abit of improvement in ball handling
# . sign in new players to help win
# . time management and players should take penalty kicks with the utmost seriousness it deserves
# .  the strikers should not just wait for the ball to come to them but actually be a sport and go get the ball
# . one player should not play all games in that they should balance and rest some players out and also give opportunity to other upcoming players
